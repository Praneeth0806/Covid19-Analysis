# %%
import pandas as pd
import numpy as  np
import plotly.express as px
import seaborn as sns
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/country_wise_latest.csv")

# %%
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
# 3                    6.48                  884             23
# 4                   16.94                  749            201
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe
# 2              18.07                 Africa
# 3               2.60                 Europe
# 4              26.84                 Africa

# %%
df.tail()
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 182                    2.08                 8916           1705
# 183                   12.50                   10              0
# 184                   57.98                 1619             72
# 185                    4.97                 3326           1226
# 186                    6.64                 1713            991
#
#      1 week % increase             WHO Region
# 182              19.12  Eastern Mediterranean
# 183               0.00                 Africa
# 184               4.45  Eastern Mediterranean
# 185              36.86                 Africa
# 186              57.85                 Africa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
#  14  WHO Region              187 non-null    object
# dtypes: float64(4), int64(9), object(2)
# memory usage: 22.0+ KB

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# std     120.037173    4197.719635            3.454302              26.287694
# min       0.000000       0.000000            0.000000               0.000000
# 25%       0.000000       0.000000            0.945000              48.770000
# 50%       1.000000      22.000000            2.150000              71.320000
# 75%       6.000000     221.000000            3.875000              86.885000
# max    1076.000000   33728.000000           28.560000             100.000000
#
#        Deaths / 100 Recovered  Confirmed last week  1 week change  \
# count                  187.00         1.870000e+02     187.000000
# mean                      inf         7.868248e+04    9448.459893
# std                       NaN         3.382737e+05   47491.127684
# min                      0.00         1.000000e+01     -47.000000
# 25%                      1.45         1.051500e+03      49.000000
# 50%                      3.62         5.020000e+03     432.000000
# 75%                      6.44         3.708050e+04    3172.000000
# max                       inf         3.834677e+06  455582.000000
#
#        1 week % increase
# count         187.000000
# mean           13.606203
# std            24.509838
# min            -3.840000
# 25%             2.775000
# 50%             6.890000
# 75%            16.855000
# max           226.320000

# %%
df.nunique()
# Out:
# Country/Region            187
# Confirmed                 184
# Deaths                    150
# Recovered                 178
# Active                    173
# New cases                 122
# New deaths                 38
# New recovered             103
# Deaths / 100 Cases        145
# Recovered / 100 Cases     177
# Deaths / 100 Recovered    155
# Confirmed last week       183
# 1 week change             162
# 1 week % increase         169
# WHO Region                  6
# dtype: int64

# %%
df.dtypes[df.dtypes == 'int64']
# Out:
# Confirmed              int64
# Deaths                 int64
# Recovered              int64
# Active                 int64
# New cases              int64
# New deaths             int64
# New recovered          int64
# Confirmed last week    int64
# 1 week change          int64
# dtype: object

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().any()
# Out:
# Country/Region            False
# Confirmed                 False
# Deaths                    False
# Recovered                 False
# Active                    False
# New cases                 False
# New deaths                False
# New recovered             False
# Deaths / 100 Cases        False
# Recovered / 100 Cases     False
# Deaths / 100 Recovered    False
# Confirmed last week       False
# 1 week change             False
# 1 week % increase         False
# WHO Region                False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
max_cov = df[['Country/Region' , 'Confirmed']]

# %%
max_cov = max_cov.sort_values(ascending = False , by = 'Confirmed')[0:5]

# %%
plt.pie(max_cov['Confirmed'],labels = max_cov['Country/Region'],shadow = True , autopct= "%0.2f%%",radius = 1.7,labeldistance=1.1,startangle = 0
       , textprops = {'fontsize':10},wedgeprops = {'linewidth':5});
plt.legend(loc =5)

# %%
max_dth = df[['Country/Region','Deaths']]

# %%
max_dth = max_dth.sort_values(ascending = False , by = 'Deaths')[0:5]
plt.pie(max_dth['Deaths'] , labels = max_dth['Country/Region'] , shadow = True , autopct = "%0.2f%%" , radius = 1.7
       ,textprops = {'fontsize':10},wedgeprops = {'linewidth':5});
plt.legend(loc = 5)

# %%
rec_data = df[['Country/Region','Recovered']]

# %%
rec_data = rec_data.sort_values(ascending=False , by = 'Recovered')[0:5]
plt.pie(rec_data['Recovered'] , labels = rec_data['Country/Region'],shadow = True,autopct = "%0.2f%%"
       ,radius = 1.7 , textprops = {'fontsize':10},wedgeprops = {'linewidth':5});
plt.legend(loc = 5)

# %%
act_data = df[['Country/Region' , 'Active']]

# %%
act_data =act_data.sort_values(ascending = False , by = 'Active')[0:5]
plt.pie(act_data['Active'],labels =act_data['Country/Region'],shadow = True , autopct = "%0.2f%%" , radius = 1.7,
        textprops = {'fontsize':10},wedgeprops = {'linewidth':5});

# %%
newdt_data = df[['Country/Region' , 'New deaths']]

# %%
newdt_data = newdt_data.sort_values(ascending = False , by = 'New deaths')[0:5]
plt.pie(newdt_data['New deaths'] , labels = newdt_data['Country/Region'],autopct = "%0.2f%%" , shadow = True
       , radius = 1.7 , textprops = {'fontsize':10},wedgeprops = {'linewidth':5});

# %%
newrc_data = df[['Country/Region' , 'New recovered']]

# %%
newrc_data = newrc_data.sort_values(ascending = False , by = 'New recovered')[0:5]
plt.pie(newrc_data['New recovered'] , labels = newrc_data['Country/Region'],autopct = "%0.2f%%" , shadow = True
       , radius = 1.7 , textprops = {'fontsize':10},wedgeprops = {'linewidth':5});

# %%
freq_death = df[['Country/Region','Deaths / 100 Cases']]

# %%
freq_death = freq_death.sort_values(ascending = False,by= 'Deaths / 100 Cases')[0:5]
sns.barplot(freq_death , y = 'Country/Region' , x = 'Deaths / 100 Cases')
# Out:
# <Axes: xlabel='Deaths / 100 Cases', ylabel='Country/Region'>

# %%
freq_recv = df[['Country/Region','Recovered / 100 Cases']]

# %%
freq_recv = freq_recv.sort_values(ascending = False,by= 'Recovered / 100 Cases')[0:5]
sns.barplot(freq_recv , y = 'Country/Region' , x = 'Recovered / 100 Cases')
# Out:
# <Axes: xlabel='Recovered / 100 Cases', ylabel='Country/Region'>

# %%
Recovered_number=df['Recovered']
Deaths_number=df['Deaths']
Recovered_number = np.array(Recovered_number)
Deaths_number = np.array(Deaths_number)
color_map = np.where(Deaths_number < 1000, 'green', 'red')
plt.scatter(Recovered_number, Deaths_number, color=color_map)
x_label = plt.xlabel('Recovered Number')
x_label.set_color('blue')
y_label = plt.ylabel('Deaths Number')
y_label.set_color('blue')
plt.title('Relationship between Recover Number and Deaths Number')
plt.show()

# %%
bar_color = ['#FF00FF', '#FFC0CB', '#800080', '#764257'][::-1]

Fig = px.bar(
    df.nlargest(5, 'Confirmed')[::-1],
    y='Country/Region',
    x=['Confirmed', 'Deaths', 'Recovered', 'Active'],
    template='plotly_dark',
    title='Most Affected Countries',
    color_discrete_sequence=bar_color,
    height=800
)

Fig.update_xaxes(tickangle=270)
Fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="67e7d4a7-a320-48ba-89a1-c20cde507a06" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67e7d4a7-a320-48ba-89a1-c20cde507a06")) {                    Plotly.newPlot(                        "67e7d4a7-a320-48ba-89a1-c20cde507a06",                        [{"alignmentgroup":"True","hovertemplate":"variable=Confirmed<br>value=%{x}<br>Country/Region=%{y}<extra></extra>","legendgroup":"Confirmed","marker":{"color":"#764257","pattern":{"shape":""}},"name":"Confirmed","offsetgroup":"Confirmed","orientation":"h","showlegend":true,"textposition":"auto","x":[452529,816680,1480073,2442375,4290259],"xaxis":"x","y":["South Africa","Russia","India","Brazil","US"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Deaths<br>value=%{x}<br>Country/Region=%{y}<extra></extra>","legendgroup":"Deaths","marker":{"color":"#800080","pattern":{"shape":""}},"name":"Deaths","offsetgroup":"Deaths","orientation":"h","showlegend":true,"textposition":"auto","x":[7067,13334,33408,87618,148011],"xaxis":"x","y":["South Africa","Russia","India","Brazil","US"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Recovered<br>value=%{x}<br>Country/Region=%{y}<extra></extra>","legendgroup":"Recovered","marker":{"color":"#FFC0CB","pattern":{"shape":""}},"name":"Recovered","offsetgroup":"Recovered","orientation":"h","showlegend":true,"textposition":"auto","x":[274925,602249,951166,1846641,1325804],"xaxis":"x","y":["South Africa","Russia","India","Brazil","US"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Active<br>value=%{x}<br>Country/Region=%{y}<extra></extra>","legendgroup":"Active","marker":{"color":"#FF00FF","pattern":{"shape":""}},"name":"Active","offsetgroup":"Active","orientation":"h","showlegend":true,"textposition":"auto","x":[170537,201097,495499,508116,2816444],"xaxis":"x","y":["South Africa","Russia","India","Brazil","US"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444 ...
